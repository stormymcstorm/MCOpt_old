# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from mcopt import MorseComplex

# %% [markdown]
# # Load Morse Complex

# %%
mc = MorseComplex.read('../gen_complexes/sinusoidal')

# %%
mc.separatrices_cell_data
# Out:
#          SourceId  DestinationId  SeparatrixId  SeparatrixType  \
# Cell Id
# 0              69              0             0               0
# 1              69              0             0               0
# 2              69              0             0               0
# 3              69              0             0               0
# 4              69              0             0               0
# ...           ...            ...           ...             ...
# 1747        29558           9999            47               0
# 1748        29558           9999            47               0
# 1749        29558           9999            47               0
# 1750        29558           9999            47               0
# 1751        29558           9999            47               0
#
#          SeparatrixFunctionMaximum  SeparatrixFunctionMinimum  \
# Cell Id
# 0                        -0.283251                  -0.848778
# 1                        -0.283251                  -0.848778
# ...
